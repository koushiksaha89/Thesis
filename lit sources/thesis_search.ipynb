# %%
import pandas as pd

# %%
df = pd.read_csv('../data/export2021.06.20-02.06.24_Customer segmentation_IEEE.csv')

# %%
df['keyword_present'] = df['Document Title'].apply(lambda x : 'Segmentation' in x)

# %%
present = df[df['keyword_present']==True]
present['Publication Year'] = present['Publication Year'].apply(lambda x:int(x))
present = present.sort_values(by=['Publication Year'], ascending=False)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
pd.options.display.max_colwidth = 500
pd.options.display.max_rows = 500

# %%
present[['Document Title','Publication Year']]
# Out:
#                            Multicriteria Market Segmentation: An Outranking Approach
# 193                                                                                                      Context-Refined Neural Cell Instance Segmentation
# 149                                                                                        Adaptive Resonance Theory 2 for RFM Based Customer Segmentation
# 196                                                                                Segmentation problem in direct market campaigns: Modified Bat Algorithm
# 370                                                                      Use Product Segmentation to Enhance the Competitiveness of Enterprises in the IoT
# 373                                                                             Vehicle Distance Measurement Tuning using Haversine and Micro-Segmentation
# 150                                                                      Policies Adoption for Supply Disruption Mitigation Based on Customer Segmentation
# 16                                                                                  Prediction of Business User Segmentation Model Based on Customer Value
# 15                                                 E-Commerce Market Segmentation Based On The Antecedents Of Customer Satisfaction and Customer Retention
# 48                                                                                        Customer Segmentation Based on RFM Value Using K-Means Algorithm
# 211                                        RFM Based Market Segmentation Approach Using Advanced K-means and Agglomerative Clustering: A Comparative Study
# 146                                                                                             Customer Segmentation for East African Microgrid Consumers
# 136                                                             A Systematic Approach to Customer Segmentation and Buyer Targeting for Profit Maximization
# 24                                                          Using Data Analytics for Customers Segmentation: Experimental Study at a Financial Institution
# 42                                                                                                          Customer Segmentation using K-means Clustering
# 18                                                                                     Benefit Segmentation of Online Customer Reviews Using Random Forest
# 219                                              Electricity Consumption and Load Profile Segmentation Analysis for Rural Micro Grid Customers in Tanzania
# 237                                                                                                   TV News Story Segmentation Using Deep Neural Network
# 304                                                                          Consumer Segmentation Using Case Based Reasoning Approach To Printing Company
# 359                                                  Online Call Scene Segmentation of Contact Center Dialogues based on Role Aware Hierarchical LSTM-RNNs
# 31                                                               Customer Segmentation based on RFM model and Clustering Techniques With K-Means Algorithm
# 78                                                                                   Customer Segmentation Using Two-Step Mining Method Based on RFM Model
# 101                                                  PurTreeClust: A Clustering Algorithm for Customer Segmentation from Massive Customer Transaction Data
# 238                                  Interest Recognition from Online Instant Messaging Sessions Using Text Segmentation and Document Embedding Techniques
# 66                                                                                Customer Segmentation in XYZ Bank Using K-Means and K-Medoids Clustering
# 22                                                                                 A Case Study on Customer Segmentation by using Machine Learning Methods
# 88                                                     Segmentation of Residential Customer Load Profile in Peninsular Malaysia using Jenks Natural Breaks
# 323                                                                                                Lifestyle Segmentation Based on Energy Consumption Data
# 284                                                                        Mining Twitter to Identify Customers’ Requirements and Shoe Market Segmentation
# 160            An Integration of Requirement Forecasting and Customer Segmentation Models towards Prescriptive Analytics For Electrical Devices Production
# 99                      Customer Segmentation and Strategy Development Based on User Behavior Analysis, RFM Model and Data Mining Techniques: A Case Study
# 326                                                                           Customer Segmentation in a Travel Agency Dataset using Clustering Algorithms
# 353                                                                     Incorporating Social Network Thai Text Mining with Lifestyle Segmentation Analysis
# 324                                                                    Segmentation of low voltage consumers for designing individualized pricing policies
# 132                                                       Trajectory Segmentation for a Recommendation Module of a Customer Relationship Management System
# 27                                                                            The Research and Application of Customer Segmentation on E-Commerce Websites
# 325                                                                 Segmentation of Factories on Electricity Consumption Behaviors Using Load Profile Data
# 182  Development of Segmentation Algorithm for Identifying VOCs (Voice of Customers) with Sales Potential and Those with Negative Attitude at Call Centers
# 320                                                                                   Does it Fit Me Better? User Segmentation in Requirements Engineering
# 242                                                                      A Multi-view Non-parametric Clustering Approach to Mobile Subscriber Segmentation
# 307                                          Segmentation of online buyers and its implication in determining marketing strategies (Indonesian case study)
# 294                         Mobile Communications Market Segmentation: An Analysis of Data Combining Self-organizing Maps and Structural Equation Modeling
# 380                                           Segmentation and Classification of Commercial Building Occupants by Energy-Use Efficiency and Predictability
# 272                                                                                                   A New Segmentation Method for Broadcast Sports Video
# 121                                                                                          A Two-Phase Clustering Analysis for B2B Customer Segmentation
# 226                                                                                                        Consensus Region Merging for Image Segmentation
# 21                               A Method for Customer Demands Groups Segmentation in Product Design Based on Fuzzy Clustering and Trigonometric Functions
# 124                                                                                      Temporal Customer Segmentation Using the Self-organizing Time Map
# 259                                                                            Maintenance Algorithm of Sequential Patterns Based on Implicit Segmentation
# 130                                                                      Customer Segmentation Methods Analysis Based on the Support-Significant Structure
# 273                                             Segmentation for environmental friendly products and its implication to product design: Indonesian context
# 286                                                            Strategies for Mobile Broadband Growth: Traffic Segmentation for Better Customer Experience
# 63                                                                   Customer Segmentation and Evaluation Based on RFM, Cross-Selling and Customer Loyalty
# 36                                                                 Application of Data Mining Technology in Membership Supermarket's Customer Segmentation
# 127                                                                Using SOM-Ward Clustering and Predictive Analytics for Conducting Customer Segmentation
# 171                                                             Contextual Segmentation: Using Context to Improve Behavior Predictive Models in E-commerce
# 140                                                                                       Customer Segmentation Study of College Students Based on the RFM
# 120                                                                                      Customer Segmentation Architecture Based on Clustering Techniques
# 117                                                                  Application of Data Mining Technique in Customer Segmentation of Shipping Enterprises
# 112                                                                                                Customer Segmentation in Mobile Carrier Choice Modeling
# 11                                                                                              Research on SVC Algorithm in Customer Segmentation of KIBS
# 107                                                                            Credit Card Customer Segmentation and Target Marketing Based on Data Mining
# 29                                                        Research for Customer Segmentation of Medical Insurance Based on K-means and C&R Tree Algorithms
# 81                                                                                     A Two Phase Clustering Method for Intelligent Customer Segmentation
# 30                                                     Research and Application of Customer Segmentation Method Based on AVB Model in Mobile Interned Time
# 51                                               Research on Customer Segmentation Based on Profitability, Profit Growth Rate and Relationship Reliability
# 50                                                                                     Improved K-Means Algorithm and Application in Customer Segmentation
# 45                                                                  Improvement Research of Customer Segmentation in Knowledge Intensive Business Services
# 306                                                                                   Segmentation of consumer's purchase behavior based on neural network
# 6                                                                               Segmentation Study on Enterprise Customers Based on Data Mining Technology
# 43                                                                           Study on Application of Customer Segmentation Based on Data Mining Technology
# 163                                                                  Data Mining in Market Segmentation and Tariff Policy Design: A Telecommunication Case
# 2                                                                                                   Customer-Churn Research Based on Customer Segmentation
# 141                                                                                    SOM Clustering Analysis for Telecommunication Customer Segmentation
# 61                                                                                  Objective Cluster Analysis in Value-Based Customer Segmentation Method
# 74                                                      Research on Index System of Dynamic Customer Segmentation Based on the Case Study of China Telecom
# 90                                                                        Customer Segmentation Algorithm of Wireless Content Service Based on Ant K-Means
# 245                                                                                   Personal Financial Market Segmentation Based on Clustering Ensembles
# 94                                                                      Improving Personalization Solutions through Optimal Segmentation of Customer Bases
# 97                                                                    Application of SOM Neural Network in Customer Segmentation Model in Coal Enterprises
# 98                                                                         Research on Customer Segmentation Based on a Two-Stage SOM Clustering Algorithm
# 55                                                                                Customer Segmentation Based on a Novel Hierarchical Clustering Algorithm
# 215                                                                                 Study on Mechanism and Models of Customer Segmentation of C2C Shopping
# 119                                                           Study on the Segmentation Method of the Air Freight Customers Based on Business Intelligence
# 313                                                                                    The Effect of Context on the Predictive Performance of Segmentation
# 56                                                                                  Customer Segmentation Model Based on Retail Consumer Behavior Analysis
# 5                                                       RFM Value and Grey Relation Based Customer Segmentation Model in the Logistics Market Segmentation
# 159                                                           Using Contextual Information in Transactional Segmentation: An Empirical Study in E-Commerce
# 190                                                                        Applying Incremental Ant Colony Clustering to Value-Based Customer Segmentation
# 220                                                                                          A SOM-Based Framework for Regional Segmentations of Customers
# 405                      An Empirical Study on Consumption Values of Leisurewear of Chinese University Students: Market Segmentation and Brand Positioning
# 290                                                                                     Improving Logistical Performance through Supply Chain Segmentation
# 41                                                              Research on Segmentation Implementation Process of Air Cargo Customer Based on Data Mining
# 108                                                                             The Segmentation of the Air Cargo Customers Based on Business Intelligence
# 396                                                                Integrating Decision Trees and Cognitive Maps for Market Segmentation in Service Sector
# 459                                                       Web Personalisation Through Incremental Individual Profiling and Support-based User Segmentation
# 91                                                       Customer Segmentation of Port Based on the Multi-instance Kernel K-aggregate Clustering Algorithm
# 369                                                                                       Evaluation of 802.16 Tariff Proportion on Segmentation Scenarios
# 349                                                                                     Risk Control and Estimation of Online Services Market Segmentation
# 157                                                                                                      Customer Segmentation Based on Survival Character
# 67                                                                                        Customer Sample Difference-oriented Bayes Segmentation Algorithm
# 52                                                  A Kernel Aggregate Clustering Approach for Mixed Data Set and Its Application in Customer Segmentation
# 84                                                                                     A Purchasing Sequences Data Mining Method for Customer Segmentation
# 20                                                                      Improving Personalization Solutions through Optimal Segmentation of Customer Bases
# 12                                                      The Simulation Research on Inventory Control of Distribution System Based on Customer Segmentation
#
#      Publication Year
# 269              2021
# 252              2021
# 82               2021
# 223              2021
# 137              2020
# 162              2020
# 60               2020
# 69               2020
# 75               2020
# 79               2020
# 103              2020
# 142              2020
# 153              2020
# 201              2020
# 199              2020
# 44               2020
# 225              2020
# 247              2020
# 315              2020
# 318              2020
# 392              2020
# 413              2020
# 54               2020
# 461              2020
# 25               2020
# 26               2020
# 8                2019
# 35               2019
# 185              2019
# 319              2019
# 96               2019
# 115              2019
# 289              2019
# 308              2019
# 221              2019
# 131              2019
# 298              2019
# 3                2019
# 104              2019
# 291              2019
# 193              2019
# 149              2019
# 196              2019
# 370              2019
# 373              2019
# 150              2019
# 16               2019
# 15               2019
# 48               2019
# 211              2019
# 146              2018
# 136              2018
# 24               2018
# 42               2018
# 18               2018
# 219              2018
# 237              2018
# 304              2018
# 359              2018
# 31               2018
# 78               2018
# 101              2018
# 238              2018
# 66               2018
# 22               2018
# 88               2018
# 323              2018
# 284              2018
# 160              2018
# 99               2018
# 326              2018
# 353              2017
# 324              2017
# 132              2017
# 27               2016
# 325              2016
# 182              2016
# 320              2016
# 242              2016
# 307              2015
# 294              2015
# 380              2015
# 272              2014
# 121              2014
# 226              2013
# 21               2013
# 124              2012
# 259              2012
# 130              2011
# 273              2011
# 286              2011
# 63               2011
# 36               2011
# 127              2010
# 171              2010
# 140              2010
# 120              2010
# 117              2010
# 112              2010
# 11               2010
# 107              2010
# 29               2010
# 81               2010
# 30               2010
# 51               2010
# 50               2010
# 45               2010
# 306              2009
# 6                2009
# 43               2009
# 163              2009
# 2                2009
# 141              2009
# 61               2009
# 74               2009
# 90               2009
# 245              2009
# 94               2009
# 97               2009
# 98               2009
# 55               2009
# 215              2009
# 119              2008
# 313              2008
# 56               2008
# 5                2008
# 159              2008
# 190              2008
# 220              2008
# 405              2008
# 290              2008
# 41               2008
# 108              2008
# 396              2007
# 459              2007
# 91               2007
# 369              2007
# 349              2007
# 157              2007
# 67               2006
# 52               2006
# 84               2006
# 20               2006
# 12               2006
